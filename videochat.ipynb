# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarandeep97/Video-Chatbot/blob/main/videochat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install git+https://github.com/huggingface/transformers accelerate flash_attn
# !pip -q install qwen_vl_utils av
# !pip -q install git+https://github.com/juanbindez/pytubefix.git
# !pip -q install moviepy
# !pip -q install datasets
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
from pytubefix import YouTube

def download_video(youtube_url, output_path='videos/', filename=None):
    try:
        yt = YouTube(youtube_url)
        stream = yt.streams.filter(progressive=True, file_extension='mp4') \
                           .order_by('resolution') \
                           .desc() \
                           .first()


        stream.download(output_path=output_path, filename=filename)
        print(f"Downloaded: {filename if filename else stream.default_filename} at {output_path}")
    except Exception as e:
        print(f"An error occurred: {e}")


video_url = 'https://www.youtube.com/watch?v=L3374C3OyrY'
download_video(video_url, filename='vid.mp4')
# Out:
# Downloaded: vid.mp4 at videos/

# %%
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info

model_name = "Qwen/Qwen2-VL-2B-Instruct"

# Load model and processor
model = Qwen2VLForConditionalGeneration.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto")

processor = AutoProcessor.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
questions = [
    "Explain the technique to kick the ball?",
    "What is the best defensive move shown in the video?",
    "Describe the player's strategy for winning the match?"
]

messages = {
    "role": "user",
    "content": [
        {
            "type": "video",
            "video": "/content/videos/vid.mp4",
            "max_pixels": 360 * 420,
            "fps": 1.0,
        }
    ]
}

q_and_a_list = []

for question in questions:
    message_with_question = messages.copy()
    message_with_question["content"].append({
        "type": "text",
        "text": question
    })

    # Prepare input for the model
    text = processor.apply_chat_template([message_with_question], tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs = process_vision_info([message_with_question])
    inputs = processor(text=[text], videos=video_inputs, return_tensors="pt", padding=True).to("cuda")

    # Run inference and get output
    output_ids = model.generate(**inputs, max_new_tokens=512)
    output_text = processor.batch_decode(output_ids, skip_special_tokens=True)

    # Store the question and its corresponding answer
    q_and_a_list.append({
        "q": question,
        "a": output_text[0].splitlines()[-1]  # Format answer properly
    })

# Display the formatted output as Question-Answer pairs
for idx, q_and_a in enumerate(q_and_a_list):
    print(f"Q{idx + 1}: {q_and_a['q']}")
    print(f"A{idx + 1}: {q_and_a['a']}\n")
# Out:
# qwen-vl-utils using decord to read video.
# Q1: Explain the technique to kick the ball?
# A1: The person in the video demonstrates the technique of kicking the ball by placing their foot on it and then kicking it with their other foot. This is a common technique used in soccer to control the ball and make precise passes.
#
# Q2: What is the best defensive move shown in the video?
# A2: The video showcases a technique where the player kicks the ball with the heel of the foot, which is a common and effective way to control the ball and make precise passes. The video also highlights the importance of proper footwork and technique in soccer, as demonstrated by the player's ability to control the ball with precision and power.
#
# Q3: Describe the player's strategy for winning the match?
# ...

# %%
from datasets import load_dataset
msrvtt = load_dataset("AlexZigma/msr-vtt")

# %%
from pytubefix import YouTube
import os

def get_caption_video_data(dataset):
    captions = [entry['caption'] for entry in dataset]
    urls = [entry['url'] for entry in dataset]
    return captions, urls

def download_multiple_videos(video_urls, output_path='vids/'):
    os.makedirs(output_path, exist_ok=True)
    downloaded_indices = []
    failed_urls = []

    for index, url in enumerate(video_urls):
        try:
            yt = YouTube(url)
            stream = yt.streams.filter(progressive=True, file_extension='mp4') \
                               .order_by('resolution') \
                               .desc() \
                               .first()
            filename = yt.video_id + '.mp4'
            stream.download(output_path=output_path, filename=filename)
            print(f"Downloaded: {filename} from {url}")
            downloaded_indices.append(index)
        except Exception as e:
            print(f"An error occurred while downloading {url}: {e}")
            failed_urls.append(url)

    return downloaded_indices, failed_urls

captions, urls = get_caption_video_data(msrvtt['val'])
downloaded_indices, failed_indices = download_multiple_videos(urls[:100])

filtered_captions = [captions[i] for i in downloaded_indices]
filtered_urls = [urls[i] for i in downloaded_indices]

print(f"\nSuccessfully downloaded videos: {len(filtered_captions)}")
print(f"Failed downloads: {len(failed_indices)}")
# Out:
# Downloaded: A9pM9iOuAzM.mp4 from https://www.youtube.com/watch?v=A9pM9iOuAzM
# Downloaded: Vs0QoCtvJmk.mp4 from https://www.youtube.com/watch?v=Vs0QoCtvJmk
# Downloaded: xQyZYPZT0tI.mp4 from https://www.youtube.com/watch?v=xQyZYPZT0tI
# An error occurred while downloading https://www.youtube.com/watch?v=BFLLzIhKLBs: BFLLzIhKLBs is unavailable
# Downloaded: 4eAgsrEX_CA.mp4 from https://www.youtube.com/watch?v=4eAgsrEX_CA
# Downloaded: JizcV7kYuqM.mp4 from https://www.youtube.com/watch?v=JizcV7kYuqM
# An error occurred while downloading https://www.youtube.com/watch?v=BqCH73FdxTg: BqCH73FdxTg is unavailable
# Downloaded: tP-TF-feFDM.mp4 from https://www.youtube.com/watch?v=tP-TF-feFDM
# An error occurred while downloading https://www.youtube.com/watch?v=j7oIlncxZOM: j7oIlncxZOM is unavailable
# An error occurred while downloading https://www.youtube.com/watch?v=TyiYdofkCCk: TyiYdofkCCk is unavailable
# Downloaded: ylSh0dOsd8Q.mp4 from https://www.youtube.com/watch?v=ylSh0dOsd8Q
# ...

# %%
from moviepy.editor import VideoFileClip
import os

def compress_videos(video_paths, output_dir="compressed_vids", target_resolution=(360, 420), fps=5, max_duration=15):
    os.makedirs(output_dir, exist_ok=True)
    compressed_video_paths = []

    for video_path in video_paths:
        try:
            clip = VideoFileClip(video_path)
            if clip.duration > max_duration:
                clip = clip.subclip(0, max_duration)
            clip_resized = clip.resize(height=target_resolution[0], width=target_resolution[1]).set_fps(fps)
            video_name = os.path.basename(video_path)
            compressed_video_path = os.path.join(output_dir, f"{video_name}")
            clip_resized.write_videofile(compressed_video_path, codec="libx264", audio_codec="aac", preset="medium")
            compressed_video_paths.append(compressed_video_path)
            clip.close()
        except Exception as e:
            print(f"Failed to process {video_path}: {e}")

    return compressed_video_paths

# %%
downloaded_video_paths = [f'/content/vids/{os.path.basename(url).split("=")[1]}.mp4' for url in filtered_urls]

compressed_video_paths = compress_videos(downloaded_video_paths)
# Out:
# Moviepy - Building video compressed_vids/A9pM9iOuAzM.mp4.
# MoviePy - Writing audio in A9pM9iOuAzMTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video compressed_vids/A9pM9iOuAzM.mp4
# Moviepy - Done !
# Moviepy - video ready compressed_vids/A9pM9iOuAzM.mp4
# Moviepy - Building video compressed_vids/Vs0QoCtvJmk.mp4.
# MoviePy - Writing audio in Vs0QoCtvJmkTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video compressed_vids/Vs0QoCtvJmk.mp4
# Moviepy - Done !
# Moviepy - video ready compressed_vids/Vs0QoCtvJmk.mp4
# Moviepy - Building video compressed_vids/xQyZYPZT0tI.mp4.
# MoviePy - Writing audio in xQyZYPZT0tITEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video compressed_vids/xQyZYPZT0tI.mp4
# Moviepy - Done !
# Moviepy - video ready compressed_vids/xQyZYPZT0tI.mp4
# Moviepy - Building video compressed_vids/4eAgsrEX_CA.mp4.
# MoviePy - Writing audio in 4eAgsrEX_CATEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# ...

# %%
questions = [
    "Summarize this video in a sentence",
]

def generate_descriptions(video_paths):
    q_and_a_list = []

    for video_path in video_paths:
        # Prepare the messages for each video
        messages = {
            "role": "user",
            "content": [
                {
                    "type": "video",
                    "video": video_path,  # Use the current video's path
                    "max_pixels": 360 * 420,
                    "fps": 1.0,
                }
            ]
        }

        for question in questions:
            # Create a copy of the message and add the question
            message_with_question = messages.copy()
            message_with_question["content"].append({
                "type": "text",
                "text": question
            })

            # Prepare input for the model
            text = processor.apply_chat_template([message_with_question], tokenize=False, add_generation_prompt=True)
            image_inputs, video_inputs = process_vision_info([message_with_question])
            inputs = processor(text=[text], videos=video_inputs, return_tensors="pt", padding=True).to("cuda")

            # Run inference and get output
            output_ids = model.generate(**inputs, max_new_tokens=512)
            output_text = processor.batch_decode(output_ids, skip_special_tokens=True)

            # Store the question and its corresponding answer
            q_and_a_list.append({
                "video": video_path,  # Include the video path for reference
                "q": question,
                "a": output_text[0].splitlines()[-1]  # Format answer properly
            })

    return q_and_a_list

downloaded_video_paths = [f'/content/compressed_vids/{os.path.basename(url).split("=")[1]}.mp4' for url in filtered_urls]
q_and_a_list = generate_descriptions(downloaded_video_paths)

# Display the formatted output as Question-Answer pairs
for idx, q_and_a in enumerate(q_and_a_list):
    print(f"Video: {q_and_a['video']}")
    print(f"Q{idx + 1}: {q_and_a['q']}")
    print(f"A{idx + 1}: {q_and_a['a']}\n")
# Out:
# It looks like you are trying to rescale already rescaled images. If the input images have pixel values between 0 and 1, set `do_rescale=False` to avoid rescaling them again.
# Video: /content/compressed_vids/A9pM9iOuAzM.mp4
# Q1: Summarize this video in a sentence
# A1: The video shows a man and a woman sitting on a blanket, eating snacks and playing cards.
#
# Video: /content/compressed_vids/Vs0QoCtvJmk.mp4
# Q2: Summarize this video in a sentence
# A2: A man is snowboarding down a hill when a truck drives by.
#
# Video: /content/compressed_vids/xQyZYPZT0tI.mp4
# Q3: Summarize this video in a sentence
# A3: The video shows a chef preparing a dish of noodles and vegetables.
#
# Video: /content/compressed_vids/4eAgsrEX_CA.mp4
# Q4: Summarize this video in a sentence
# A4: The video shows a group of people fighting in a battle, and then a man in a red cape is shown.
#
# Video: /content/compressed_vids/JizcV7kYuqM.mp4
# Q5: Summarize this video in a sentence
# ...

# %%
# !pip install -q rouge_score
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
import nltk

nltk.download('wordnet')

generated_answers = [d['a'] for d in q_and_a_list]

caps = filtered_captions


bleu_references = [[ref.split() for ref in refs] for refs in caps]
bleu_hypotheses = [gen.split() for gen in generated_answers]
average_bleu = corpus_bleu(bleu_references, bleu_hypotheses)

meteor_scores = [
    max(meteor_score([ref.split()], gen.split()) for ref in refs)  # Split both ref and gen into words
    for refs, gen in zip(caps, generated_answers)
]
average_meteor = sum(meteor_scores) / len(meteor_scores)


rouge_scorer_instance = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
rouge_l_scores = [max(rouge_scorer_instance.score(ref, gen)['rougeL'].fmeasure
                      for ref in refs)
                  for refs, gen in zip(caps, generated_answers)]
average_rouge_l = sum(rouge_l_scores) / len(rouge_l_scores)

print(f"Average BLEU Score: {average_bleu:.4f}")
print(f"Average METEOR Score: {average_meteor:.4f}")
print(f"Average ROUGE-L Score: {average_rouge_l:.4f}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# ...
